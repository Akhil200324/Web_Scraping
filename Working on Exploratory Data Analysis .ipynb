# %% [markdown]
# #Data Analysis - Numpy(Numerical Python)
#                - Pandas (tabular data)
#
# Visualization -> matplotlib,plotly (user)

# %% [markdown]
# pip install numpy
# pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
#Creation of arrays
a = [1,5,6.3,3]
print(len(a))
b = np.array(a) #source is list as numpy arrays are more efficient
b
# Out:
# 4
# array([1. , 5. , 6.3, 3. ])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
print(b.size) #number of elements
print(b.ndim) #dimension of array
# Out:
# 4
# 1

# %%
#2-Dimension arrays
a = [[1,2,5,6],[5,8,5,6]]
len(a)
# Out:
# 2

# %%
b = np.array(a)
print(b)
print(b.ndim)
print(b.size)
print(b.shape)#shape -->rows and columns
# Out:
# [[1 2 5 6]
#  [5 8 5 6]]
# 2
# 8
# (2, 4)

# %%
#Element wise operations
print(b+b) #Addition of arrays
print(b*b)
print(b/b)
# Out:
# [[ 2  4 10 12]
#  [10 16 10 12]]
# [[ 1  4 25 36]
#  [25 64 25 36]]
# [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]

# %%
b
# Out:
# array([[1, 2, 5, 6],
#        [5, 8, 5, 6]])

# %%
#indexing and slicing
len(b)
# Out:
# 2

# %%
c = np.array([[1,5,8,9],
             [2,6,9,-3],
             [3,7,12,36]])
print(c)
print(c.shape)
print(c.size) #size -->prdct of rows and columns
# Out:
# [[ 1  5  8  9]
#  [ 2  6  9 -3]
#  [ 3  7 12 36]]
# (3, 4)
# 12

# %%
c[0]
# Out:
# array([1, 5, 8, 9])

# %%
c[0][2] #subindexing
# Out:
# 8

# %%
#Accessing column wise data
c[:,1]
# Out:
# array([5, 6, 7])

# %%
c
# Out:
# array([[ 1,  5,  8,  9],
#        [ 2,  6,  9, -3],
#        [ 3,  7, 12, 36]])

# %%
c[1:,2:]
# Out:
# array([[ 9, -3],
#        [12, 36]])

# %%
c
# Out:
# array([[ 1,  5,  8,  9],
#        [ 2,  6,  9, -3],
#        [ 3,  7, 12, 36]])

# %%
type(c)
# Out:
# numpy.ndarray

# %% [markdown]
# In 2008, developer Wes McKinney started developing pandas when in need of high
# performance, flexible tool for analysis of data.
#
# Pandas gives Python the ability to work with spreadsheet-like data for fast data
# loading,manipulating,aligning and merging
#
# **Series and DataFrame**
#
# DataFrame respresents entire spreadsheet whereas Series is a single column of the dataframe
#
# #Pandas -->Series(1 dimensional data representation) (column in a table)
# #DataFrame -->2 dimensional data representation (table consisting of rows and columns)
#
#
# Pandas -->1-Dimensinal data representation -->Series
#
#        -->2-Dimensional data represntatiob -->DataFrame

# %%
d = pd.Series([5,8,9]) #Series(data,index,dtype,copy) #index -->default index -->0
d
e = pd.Series({'name':'Codegnan',
               'place':'vjwda'})
#keys will be index for Series
e
# Out:
# name     Codegnan
# place       vjwda
# dtype: object

# %%
#DataFrame ->2-Dimensional data representation
#tabular data -->rows and columns
c
# Out:
# array([[ 1,  5,  8,  9],
#        [ 2,  6,  9, -3],
#        [ 3,  7, 12, 36]])

# %%
data =pd.DataFrame(c) #DataFrame(data,index,columns)
data
# Out:
#    0  1   2   3
# 0  1  5   8   9
# 1  2  6   9  -3
# 2  3  7  12  36

# %%
#we can customize rows(index) and columns
data = pd.DataFrame(c,
                    index=[1,2,3],
                    columns=[1,2,3,4])
data
# Out:
#    1  2   3   4
# 1  1  5   8   9
# 2  2  6   9  -3
# 3  3  7  12  36

# %% [markdown]
# Steps in Data Analysis
#
# -->Understand the Problem (what columns you have wht to do)
# -->Checking for the count of values in each column
# -->Filling the missing values and dropping unnecessary columns
# -->Give a better visualization for imprtnt features(columns)

# %%
#Case-Study for Exploratory Data Analysis on Titanic dataset
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Check the column names
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#to get the complete information of dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#To get the count of missing values in dataframe
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#to get the unique count in each column
data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#we can get the count for Sex,Pclass,Embarked
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#data['Age'].value_counts()

# %%
#data['Name'].value_counts()

# %%
#pip install matplotlib

# %%
#let's get some insights with visulization -->matplotlib
import matplotlib

# %%
#help(matplotlib) #use help,type,dir

# %%
import matplotlib.pyplot as plt

# %%
#lets start plotting -->Histograms,Bar graphs,Pie charts
plt.hist(data['Age'])
plt.show()

# %%
data['Sex'].value_counts().plot(kind="bar")
plt.show()

# %%
data['Sex'].value_counts().plot(kind="barh")
plt.show()

# %%
data['Embarked'].value_counts().plot(kind='bar')
plt.show()

# %%
data['Survived'].value_counts().plot(kind="pie")
plt.show()

# %%
#Dropping and Filling the columns
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#As Age is an important feature where we need to fill it
data['Age'].info() #Statitical function -->mean()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 714 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB

# %%
data['Age'].mean()
# Out:
# 29.69911764705882

# %%
#Fill the age column with mean
data['Age'].fillna(data['Age'].mean(),inplace=True)
#inplace will make permanent changes in dataframe

# %%
data['Age'].isnull().sum()
# Out:
# 0
